# %% [markdown]
# # Analyzing COVID-19 Data in Python

# %% [markdown]
# # Data Source

# %% [markdown]
# The data is from the European Centre for Disease Prevention and Control
#
# COVID-19 is a fast spreading novel coronavirus that is categorized as a pandemic.

# %%
# %matplotlib inline
import pandas

# %%
df = pandas.read_excel('s3://hamilton-ia241/COVID-19-geographic-disbtribution-worldwide-2020-05-01.xlsx')
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-05-01    1      5  2020    222       4             Afghanistan
# 1     2020-04-30   30      4  2020    122       0             Afghanistan
# 2     2020-04-29   29      4  2020    124       3             Afghanistan
# 3     2020-04-28   28      4  2020    172       0             Afghanistan
# 4     2020-04-27   27      4  2020     68      10             Afghanistan
# 5     2020-04-26   26      4  2020    112       4             Afghanistan
# 6     2020-04-25   25      4  2020     70       1             Afghanistan
# 7     2020-04-24   24      4  2020    105       2             Afghanistan
# 8     2020-04-23   23      4  2020     84       4             Afghanistan
# 9     2020-04-22   22      4  2020     61       1             Afghanistan
# 10    2020-04-21   21      4  2020     35       2             Afghanistan
# 11    2020-04-20   20      4  2020     88       3             Afghanistan
# ...

# %% [markdown]
# # Average number of cases per day in 2020

# %%
avg_cases_per_day = df.groupby('dateRep').mean()['cases']

avg_cases_per_day.plot()

# %% [markdown]
# The average number of cases per day spiked mid-Febuary and increased in April.

# %% [markdown]
# # United States of America Cases related to Deaths

# %%
avg_cases_per_countriesAndTerritories = df.loc[df['countriesAndTerritories'] == 'United_States_of_America']
United_States_of_America_data.plot.scatter(x='cases',y='deaths')

# %% [markdown]
# As the number of cases in the US increased, so did deaths.

# %% [markdown]
# # The Top 20 Countries with the Highest Deaths

# %%
sum_death_by_country = df.groupby('countriesAndTerritories').sum()['deaths']
sum_death_by_country.nlargest(20).plot.bar()

# %% [markdown]
# The US has the highest death rates.

# %% [markdown]
# # Conclusions and Limitations

# %% [markdown]
# The number of cases worldwide are increasing, and have been since April. As more cases in the US increased, the deaths subsequently increased. These deaths increased greatly around 3000 US cases. The US has the highest death rates out of all countries and territories.
#
# Limtiations include:
#
#    Outdated data: Population data is from 2018 and virus data is continually updated.
#
#    Testing: Testing is not widely available so it is difficult to know the true number of COVID-19 cases and
#    related deaths.
